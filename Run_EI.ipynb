# %%
# %cd '/content/drive/My Drive/BuboQA/evidence_integration'
# Out:
# /content/drive/My Drive/BuboQA/evidence_integration

# %%
pip install fuzzywuzzy

# %%
import os
os.environ['NLTK_DATA']="/content/drive/My Drive/BuboQA/nltk_data"

# %%
# !python evidence_integration.py --ent_type transformer --ent_path ../entity_linking/results/transformer/test-h100.txt \
 --rel_type transformer --rel_path ../relation_prediction/nn/results/transformer/test.txt
# found:         99.54811638308664
# retrieved at top 1: 68.15603817955457
# retrieved at top 2: 71.01028265781343
# retrieved at top 3: 71.8218287453313
# Out:
# Namespace(data_path='../data/processed_simplequestions_dataset/test.txt', ent_path='../entity_linking/results/transformer/test-h100.txt', ent_type='transformer', heuristics=True, hits_ent=50, hits_rel=5, index_degreespath='../indexes/degrees_2M.pkl', index_reachpath='../indexes/reachability_2M.pkl', output_dir='./results', rel_path='../relation_prediction/nn/results/transformer/test.txt', rel_type='transformer', wiki_path='../data/fb2w.nt')
# Loading index map from ../indexes/reachability_2M.pkl
# Loading index map from ../indexes/degrees_2M.pkl
# Loading Wiki
# getting questions ...
# Entity Source : ../entity_linking/results/transformer/test-h100.txt
# Relation Source : ../relation_prediction/nn/results/transformer/test.txt
#
# found:              99.54811638308664
# retrieved at top 1: 68.15603817955457
# retrieved at top 2: 71.01028265781343
# retrieved at top 3: 71.8218287453313

# %%
# !python evidence_integration.py --data_path ../data/processed_simplequestions_dataset/valid.txt \
 --ent_type transformer --ent_path ../entity_linking/results/transformer/valid-h100.txt \
 --rel_type transformer --rel_path ../relation_prediction/nn/results/transformer/valid.txt
# found:         99.52843273231623
# retrieved at top 1: 70.18955154877486
# retrieved at top 2: 72.61211280628757
# retrieved at top 3: 73.47202958853444
# Out:
# Namespace(data_path='../data/processed_simplequestions_dataset/valid.txt', ent_path='../entity_linking/results/transformer/valid-h100.txt', ent_type='transformer', heuristics=True, hits_ent=50, hits_rel=5, index_degreespath='../indexes/degrees_2M.pkl', index_reachpath='../indexes/reachability_2M.pkl', output_dir='./results', rel_path='../relation_prediction/nn/results/transformer/valid.txt', rel_type='transformer', wiki_path='../data/fb2w.nt')
# Loading index map from ../indexes/reachability_2M.pkl
# Loading index map from ../indexes/degrees_2M.pkl
# Loading Wiki
# getting questions ...
# Entity Source : ../entity_linking/results/transformer/valid-h100.txt
# Relation Source : ../relation_prediction/nn/results/transformer/valid.txt
#
# found:              99.52843273231623
# retrieved at top 1: 70.18955154877486
# retrieved at top 2: 72.61211280628757
# retrieved at top 3: 73.47202958853444
