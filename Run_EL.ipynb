# %%
# %cd '/content/drive/My Drive/BuboQA/entity_linking'
# Out:
# /content/drive/My Drive/BuboQA/entity_linking

# %%
pip install fuzzywuzzy

# %%
import os
os.environ['NLTK_DATA']="/content/drive/My Drive/BuboQA/nltk_data"

# %%
# !python entity_linking.py --model_type transformer --query_dir ../entity_detection/nn/query_text/transformer
# Source : ../entity_detection/nn/query_text/transformer/query.valid
# 10815it [01:49, 98.42it/s] 
# valid
# Top1 Entity Linking Accuracy: 0.6809061488673139
# Top3 Entity Linking Accuracy: 0.7940822931114193
# Top5 Entity Linking Accuracy: 0.8275543226999538
# Top10 Entity Linking Accuracy: 0.8641701340730467
# Top20 Entity Linking Accuracy: 0.8892279241793805
# Top50 Entity Linking Accuracy: 0.912621359223301
# Top100 Entity Linking Accuracy: 0.9281553398058252
# Source : ../entity_detection/nn/query_text/transformer/query.test
# 21687it [04:04, 88.53it/s]
# test
# Top1 Entity Linking Accuracy: 0.6660211186425047
# Top3 Entity Linking Accuracy: 0.780052566053396
# Top5 Entity Linking Accuracy: 0.8144049430534421
# Top10 Entity Linking Accuracy: 0.8522156130400701
# Top20 Entity Linking Accuracy: 0.8795591829206437
# Top50 Entity Linking Accuracy: 0.9057960990455112
# Top100 Entity Linking Accuracy: 0.9228109005394937
# Out:
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Namespace(data_dir='../data/processed_simplequestions_dataset', hits=100, index_ent='../indexes/entity_2M.pkl', model_type='transformer', output_dir='./results', query_dir='../entity_detection/nn/query_text/transformer')
# Total type of text: 4798616
# Max Length of entry is 249717, text is ,
# Source : ../entity_detection/nn/query_text/transformer/query.valid
# 10815it [01:49, 98.42it/s]
# valid
# Top1 Entity Linking Accuracy: 0.6809061488673139
# Top3 Entity Linking Accuracy: 0.7940822931114193
# Top5 Entity Linking Accuracy: 0.8275543226999538
# Top10 Entity Linking Accuracy: 0.8641701340730467
# Top20 Entity Linking Accuracy: 0.8892279241793805
# Top50 Entity Linking Accuracy: 0.912621359223301
# ...
