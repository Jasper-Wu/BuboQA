# %%
from google.colab import drive
drive.mount('/content/drive/')
# %cd "drive/My Drive/"
# %cd BuboQA/
# !pwd
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive
# /content/drive/My Drive/BuboQA
# /content/drive/My Drive/BuboQA

# %%
pip install fuzzywuzzy

# %%
import os
os.environ['NLTK_DATA']="/content/drive/My Drive/BuboQA/nltk_data"

# %%
# %cd entity_detection/nn/
# Out:
# /content/drive/My Drive/BuboQA/entity_detection/nn

# %% [markdown]
# # LSTM
#
# - Early Stopping. Epoch: 99, Best Dev F1: 0.9356163751326902

# %%
# !python train.py --entity_detection_mode LSTM --fix_embed
# Early Stopping. Epoch: 99, Best Dev F1: 0.9356163751326902
# Out:
# Note: You are using GPU for training
# Embedding match number 52283 out of 61333
# Shift model to GPU
# Namespace(batch_size=32, clip_gradient=0.6, cuda=True, data_dir='../../data/processed_simplequestions_dataset', dataset='EntityDetection', dev_every=2000, entity_detection_mode='LSTM', epochs=30, gpu=0, hidden_size=300, hits=100, input_size=300, label=7, log_every=1000, lr=0.0001, num_layer=2, patience=10, results_path='query_text', rnn_dropout=0.3, rnn_fc_dropout=0.3, save_path='saved_checkpoints', seed=3435, specify_prefix='id1', train_embed=False, trained_model='', vector_cache='../../data/sq_glove300d.pt', weight_decay=0, words_dim=300, words_num=61333)
# VOCAB num 61333
# Train instance 75722
# Dev instance 10815
# Test instance 21687
# Entity Type 7
# EntityDetection(
#   (embed): Embedding(61333, 300)
#   (lstm): LSTM(300, 300, num_layers=2, dropout=0.3, bidirectional=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (relu): ReLU()
#   (hidden2tag): Sequential(
# ...

# %% [markdown]
# # Transformer - First Phase

# %% [markdown]
# ## Model Trail

# %%
# !python train.py --entity_detection_mode transformer --fix_embed # originally
# Out:
# Note: You are using GPU for training
# Embedding match number 52283 out of 61333
# Shift model to GPU
# Namespace(batch_size=32, clip_gradient=0.6, cuda=True, data_dir='../../data/processed_simplequestions_dataset', dataset='EntityDetection', dev_every=2000, dim_feedforward=2048, entity_detection_mode='transformer', epochs=30, gpu=0, hidden_size=300, hits=100, input_size=300, label=7, log_every=1000, lr=0.0001, nhead=6, num_decoder_layers=6, num_encoder_layers=6, num_layer=2, patience=10, results_path='query_text', rnn_dropout=0.3, rnn_fc_dropout=0.3, save_path='saved_checkpoints', seed=3435, specify_prefix='id1', train_embed=False, trained_model='', transformer_dropout=0.1, vector_cache='../../data/sq_glove300d.pt', weight_decay=0, words_dim=300, words_num=61333)
# VOCAB num 61333
# Train instance 75722
# Dev instance 10815
# Test instance 21687
# Entity Type 7
# TransformerModel(
#   (embed): Embedding(61333, 300)
#   (pos_encoder): PositionalEncoding(
# ...

# %%
# !python train.py --entity_detection_mode transformer --fix_embed # with src_mask
# Out:
# Note: You are using GPU for training
# Embedding match number 52283 out of 61333
# Shift model to GPU
# Namespace(batch_size=32, clip_gradient=0.6, cuda=True, data_dir='../../data/processed_simplequestions_dataset', dataset='EntityDetection', dev_every=2000, dim_feedforward=2048, entity_detection_mode='transformer', epochs=30, gpu=0, hidden_size=300, hits=100, input_size=300, label=7, log_every=1000, lr=0.0001, nhead=6, num_decoder_layers=6, num_encoder_layers=6, num_layer=2, patience=10, results_path='query_text', rnn_dropout=0.3, rnn_fc_dropout=0.3, save_path='saved_checkpoints', seed=3435, specify_prefix='id1', train_embed=False, trained_model='', transformer_dropout=0.1, vector_cache='../../data/sq_glove300d.pt', weight_decay=0, words_dim=300, words_num=61333)
# VOCAB num 61333
# Train instance 75722
# Dev instance 10815
# Test instance 21687
# Entity Type 7
# TransformerModel(
#   (embed): Embedding(61333, 300)
#   (pos_encoder): PositionalEncoding(
# ...

# %%
# !python train.py --entity_detection_mode transformer --fix_embed --transformer_dropout 0.3 # dropout = 0.3
# Out:
# Note: You are using GPU for training
# Embedding match number 52283 out of 61333
# Shift model to GPU
# Namespace(batch_size=32, clip_gradient=0.6, cuda=True, data_dir='../../data/processed_simplequestions_dataset', dataset='EntityDetection', dev_every=2000, dim_feedforward=2048, entity_detection_mode='transformer', epochs=30, gpu=0, hidden_size=300, hits=100, input_size=300, label=7, log_every=1000, lr=0.0001, nhead=6, num_decoder_layers=6, num_encoder_layers=6, num_layer=2, patience=10, results_path='query_text', rnn_dropout=0.3, rnn_fc_dropout=0.3, save_path='saved_checkpoints', seed=3435, specify_prefix='id1', train_embed=False, trained_model='', transformer_dropout=0.3, vector_cache='../../data/sq_glove300d.pt', weight_decay=0, words_dim=300, words_num=61333)
# VOCAB num 61333
# Train instance 75722
# Dev instance 10815
# Test instance 21687
# Entity Type 7
# TransformerModel(
#   (embed): Embedding(61333, 300)
#   (pos_encoder): PositionalEncoding(
# ...

# %%
# !!python train.py --entity_detection_mode transformer --fix_embed # with hidden2tag classifier layer
# Out:
# ['Note: You are using GPU for training',
#  'Embedding match number 52283 out of 61333',
#  'Shift model to GPU',
#  "Namespace(batch_size=32, clip_gradient=0.6, cuda=True, data_dir='../../data/processed_simplequestions_dataset', dataset='EntityDetection', dev_every=2000, dim_feedforward=2048, entity_detection_mode='transformer', epochs=30, gpu=0, hidden_size=300, hits=100, input_size=300, label=7, log_every=1000, lr=0.0001, nhead=6, num_decoder_layers=6, num_encoder_layers=6, num_layer=2, patience=10, results_path='query_text', rnn_dropout=0.3, rnn_fc_dropout=0.3, save_path='saved_checkpoints', seed=3435, specify_prefix='id1', train_embed=False, trained_model='', transformer_dropout=0.1, vector_cache='../../data/sq_glove300d.pt', weight_decay=0, words_dim=300, words_num=61333)",
#  'VOCAB num 61333',
#  'Train instance 75722',
#  'Dev instance 10815',
#  'Test instance 21687',
#  'Entity Type 7',
#  'TransformerModel(',
#  '  (embed): Embedding(61333, 300)',
# ...

# %%
# !!python train.py --entity_detection_mode transformer --fix_embed # with hidden2tag, without sqrt(d_model)
# Out:
# ['Note: You are using GPU for training',
#  'Embedding match number 52283 out of 61333',
#  'Shift model to GPU',
#  "Namespace(batch_size=32, clip_gradient=0.6, cuda=True, data_dir='../../data/processed_simplequestions_dataset', dataset='EntityDetection', dev_every=2000, dim_feedforward=2048, entity_detection_mode='transformer', epochs=30, gpu=0, hidden_size=300, hits=100, input_size=300, label=7, log_every=1000, lr=0.0001, nhead=6, num_decoder_layers=6, num_encoder_layers=6, num_layer=2, patience=10, results_path='query_text', rnn_dropout=0.3, rnn_fc_dropout=0.3, save_path='saved_checkpoints', seed=3435, specify_prefix='id1', train_embed=False, trained_model='', transformer_dropout=0.1, vector_cache='../../data/sq_glove300d.pt', weight_decay=0, words_dim=300, words_num=61333)",
#  'VOCAB num 61333',
#  'Train instance 75722',
#  'Dev instance 10815',
#  'Test instance 21687',
#  'Entity Type 7',
#  'TransformerModel(',
#  '  (embed): Embedding(61333, 300)',
# ...

# %% [markdown]
# ## Testing

# %%
# !python top_retrieval.py --trained_model ./saved_checkpoints/transformer/id1_best_model.pt --entity_detection_mode transformer
# Dataset: valid
# Dev Precision:  93.967026% Recall:  94.331946% F1 Score:  94.149133%
# 10815it [00:00, 108603.49it/s]
# Dataset: test
# Dev Precision:  93.514731% Recall:  94.050756% F1 Score:  93.781977%
# 21687it [00:00, 126777.89it/s]
# Out:
# Note: You are using GPU for training
# TransformerModel(
#   (embed): Embedding(61333, 300)
#   (pos_encoder): PositionalEncoding(
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): _LinearWithBias(in_features=300, out_features=300, bias=True)
#         )
#         (linear1): Linear(in_features=300, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=300, bias=True)
#         (norm1): LayerNorm((300,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((300,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.1, inplace=False)
#         (dropout2): Dropout(p=0.1, inplace=False)
#       )
#       (1): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
# ...

# %% [markdown]
# # Transformer - Second Phase
